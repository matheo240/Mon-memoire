# %% [raw]
# 1/ Récursivité:
# - le cours sera ajouté prochainement

# %% [raw]
# 2/ Graphes:
# - Le cours sera ajouté prochainement

# %% [raw]
# 3/ Arbres:
# - Le cours sera ajouté prochainement

# %% [raw]
# 4/ Piles et files:
# - Le cours sera ajouté prochainement

# %% [raw]
# 5/ SQL:
# - Le cours sera ajouté prochainement

# %% [markdown]
# # 6/ Les bases:

# %% [raw]
# - Conversion BINAIRE (base 2) vers nombre entier positif DECIMAL (base 10):
#
#      128    64    32     16      8      4      2      1
#        1     1     1      1      0      0      0      0
#
# 128 + 64 + 32 + 16 = 240
# le nombre binaire 0b1111 0000 = 240 en nombre entier positif DECIMAL

# %% [raw]
# - Conversion BINAIRE (base 2) vers nombre à virgule DECIMAL (base 10):
#
#      128    64    32     16      8      4      2      1,    0.5
#        1     1     1      1      0      0      0      0      1
#
# 128 + 64 + 32 + 16 + 0.5 = 240.5
# le nombre binaire 0b1111 0000,1 = 240.5 en nombre à virgule DECIMAL

# %% [raw]
# - Conversion BINAIRE (base 2) vers nombre entier négatif DECIMAL (base 10 - complément à 2 sur 8 bits):
#
#      128    64    32     16      8      4      2      1
#        1     1     1      1      0      0      0      0
#
# 1 + 2 + 4 + 8 - 1 = 14
# 14 - 256 = -240
# le nombre binaire 0b1111 0000 = -240 en nombre négatif DECIMAL
